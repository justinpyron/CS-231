# %%
import torch
import utils
from generator import Adversarial_utils
import matplotlib.pyplot as plt

# %% [markdown]
# # CIFAR

# %% [markdown]
# #### Create an object of class Adversarial_utils
# The Adversarial_utils class contains functionality to help generate adversarial images, such as
# - Generate adversarial images for a batch with the fool() method
# - Experiment with the parameters of the fool() method with the fool_calibrate() method
# - Visualize generated adversarial images from a random batch with _visualize() method, which is located inside fool_calibrate()

# %%
cifar_adv = Adversarial_utils('cifar')

# %%
cifar_adv.fool_calibrate(target=8, epsilon=1e-1, max_L2_norm=10, verbose=True)
# Out:
# Took 1.10 seconds
# Number in batch that model successfully predicts: 33/50
# Number that terminated before max number of iterations: 33/50
# Number successfully fooled: 33/50
# Number with small enough perturbation: 33/50
#
#
#
# Original Label: 7
# Model prediction: 8
# Original Label: 6
# Model prediction: 8
# Original Label: 5
# Model prediction: 8
# Original Label: 1
# Model prediction: 8
# Original Label: 0
# Model prediction: 8
# Original Label: 5
# Model prediction: 8
# Original Label: 0
# Model prediction: 8
# Original Label: 1
# Model prediction: 8
# Original Label: 0
# Model prediction: 8
# Original Label: 7
# Model prediction: 8
# Original Label: 7
# Model prediction: 8
# Original Label: 1
# Model prediction: 8
# Original Label: 9
# Model prediction: 8
# Original Label: 6
# Model prediction: 8
# Original Label: 0
# Model prediction: 8
# Original Label: 4
# Model prediction: 8
# Original Label: 6
# Model prediction: 8
# Original Label: 9
# Model prediction: 8
# Original Label: 9
# Model prediction: 8
# Original Label: 5
# Model prediction: 8
# Original Label: 0
# Model prediction: 8
# Original Label: 6
# Model prediction: 8
# Original Label: 3
# Model prediction: 8
# Original Label: 1
# Model prediction: 8
# Original Label: 7
# Model prediction: 8
# Original Label: 7
# Model prediction: 8
# Original Label: 5
# Model prediction: 8
# Original Label: 3
# Model prediction: 8
# Original Label: 3
# Model prediction: 8
# Original Label: 7
# Model prediction: 8
# Original Label: 4
# Model prediction: 8
# Original Label: 3
# Model prediction: 8
# Original Label: 2
# Model prediction: 8

# %% [markdown]
# # MNIST

# %%
mnist_adv = Adversarial_utils('mnist')

# %%
mnist_adv.fool_calibrate(target=4, epsilon=1e-2, num_iters=100, max_L2_norm=3.0, verbose=True)
# Out:
# Took 5.13 seconds
# Number in batch that model successfully predicts: 45/50
# Number that terminated before max number of iterations: 43/50
# Number successfully fooled: 43/50
# Number with small enough perturbation: 27/50
#
#
#
# Original Label: 7
# Model prediction: 4
# Original Label: 2
# Model prediction: 4
# Original Label: 7
# Model prediction: 4
# Original Label: 8
# Model prediction: 4
# Original Label: 7
# Model prediction: 4
# Original Label: 1
# Model prediction: 4
# Original Label: 7
# Model prediction: 4
# Original Label: 6
# Model prediction: 4
# Original Label: 9
# Model prediction: 4
# Original Label: 0
# Model prediction: 4
# Original Label: 6
# Model prediction: 4
# Original Label: 2
# Model prediction: 4
# Original Label: 8
# Model prediction: 4
# Original Label: 9
# Model prediction: 4
# Original Label: 2
# Model prediction: 4
# Original Label: 6
# Model prediction: 4
# Original Label: 9
# Model prediction: 4
# Original Label: 3
# Model prediction: 4
# Original Label: 1
# Model prediction: 4
# Original Label: 6
# Model prediction: 4
# Original Label: 1
# Model prediction: 4
# Original Label: 3
# Model prediction: 4
# Original Label: 9
# Model prediction: 4
# Original Label: 1
# Model prediction: 4
# Original Label: 1
# Model prediction: 4
# Original Label: 8
# Model prediction: 4
# Original Label: 2
# Model prediction: 4

# %% [markdown]
# # Create a dataset of adversarial images
# The make_dataset() method inside the Adversarial_utils class will create a dataset of adversarial images. The data stored will contained the following for each example:
# - The original image
# - The perturbation added to the image
# - The adversarial image
# - The original label for the image
# - The label for the class that the model gets tricked into predicting

# %%
file_name = 'mnist_test'
mnist_adv.make_dataset(file_name, num_examples=300, epsilon=1e-2,max_L2_norm=None)
# Out:
# Working on batch 0
# Working on batch 1
# Working on batch 2
# Working on batch 3
# Working on batch 4
# Working on batch 5
# Working on batch 6
# Took 6.08 minutes

# %% [markdown]
# # Load a dataset of adversarial images
# The get_adv_data() function inside utils.py will load a Pytorch dataloader object containing data for an existing dataset of adversarial images.

# %%
adv_data = utils.get_adv_data(file_name, original_label=9, target_label=8)

# %% [markdown]
# #### Plot a few examples

# %%
sample_batch = iter(adv_data).next()

originals = sample_batch[0]
adversaries = sample_batch[2]

for i in range(20):
    plt.subplot(1,2,1)
    plt.imshow(originals[i][0].numpy(), cmap='binary_r')
    plt.title('Original')
    plt.xticks([])
    plt.yticks([])

    plt.subplot(1,2,2)
    plt.imshow(adversaries[i][0].numpy(), cmap='binary_r')
    plt.title('Adversary')
    plt.xticks([])
    plt.yticks([])
    plt.show()
